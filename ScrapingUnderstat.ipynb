# %%
# information necessary to produce shot map with accurate colouring
# drop the link here for the shot data you want and run the script for
# your final data for plotting
base_url = 'https://understat.com/player/531'

# %%
# importing necessary web scraping, calculation, and visualization libraries
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import statistics
import numpy as np
import math
from mplsoccer.pitch import Pitch

# %%
# reading necessary content out of understat.com
url = base_url
res = requests.get(url)
soup = BeautifulSoup(res.content,"lxml")

scripts = soup.find_all('script')
strings = scripts[3].string

# %%
# converting raw website data into dictionary containing necessary content
ind_start = strings.index("('")+2
ind_end = strings.index("')")

json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

data = json.loads(json_data)

# %%
# converting dictionary into Pandas DataFrame conta
finaldata = pd.DataFrame.from_dict(data)
finaldata = finaldata[finaldata['situation'] != 'Penalty']
finaldata
# Out:
#          id minute       result                   X                    Y  \
# 0     55305      2    SavedShot   0.764000015258789                0.345
# 1     55306      4  BlockedShot  0.8180000305175781  0.26399999618530273
# 2     55318     55  MissedShots  0.9030000305175782                0.485
# 3     55319     60    SavedShot   0.904000015258789    0.620999984741211
# 4     55332     80  BlockedShot               0.825   0.6079999923706054
# ..      ...    ...          ...                 ...                  ...
# 374  428665     25  BlockedShot   0.870999984741211   0.6029999923706054
# 375  428668     32  BlockedShot                0.85  0.32599998474121095
# 376  428678     67         Goal  0.9119999694824219   0.6880000305175781
# 377  429871     46    SavedShot  0.8780000305175781   0.2989999961853027
# 378  429878     63  BlockedShot  0.9269999694824219   0.5729999923706055
#
#                        xG           player h_a player_id situation season  \
# 0    0.011343376711010933  Michail Antonio   h       531  OpenPlay   2015
# 1     0.02422472834587097  Michail Antonio   h       531  OpenPlay   2015
# 2     0.04558191075921059  Michail Antonio   h       531  OpenPlay   2015
# 3     0.07481948286294937  Michail Antonio   h       531  OpenPlay   2015
# 4     0.05477369204163551  Michail Antonio   h       531  OpenPlay   2015
# ..                    ...              ...  ..       ...       ...    ...
# 374   0.09253901988267899  Michail Antonio   h       531  OpenPlay   2021
# 375     0.047293521463871  Michail Antonio   h       531  OpenPlay   2021
# 376    0.2952220141887665  Michail Antonio   h       531  OpenPlay   2021
# 377  0.049746885895729065  Michail Antonio   a       531  OpenPlay   2021
# 378    0.1394081711769104  Michail Antonio   a       531  OpenPlay   2021
#
#       shotType match_id       h_team          a_team h_goals a_goals  \
# 0    RightFoot      235     West Ham           Stoke       0       0
# 1     LeftFoot      235     West Ham           Stoke       0       0
# 2         Head      235     West Ham           Stoke       0       0
# 3    RightFoot      235     West Ham           Stoke       0       0
# 4    RightFoot      235     West Ham           Stoke       0       0
# ..         ...      ...          ...             ...     ...     ...
# 374   LeftFoot    16401     West Ham  Crystal Palace       2       2
# 375   LeftFoot    16401     West Ham  Crystal Palace       2       2
# 376   LeftFoot    16401     West Ham  Crystal Palace       2       2
# 377  RightFoot    16411  Southampton        West Ham       0       0
# 378  RightFoot    16411  Southampton        West Ham       0       0
#
#                     date   player_assisted    lastAction
# 0    2015-12-12 19:00:00              None        Aerial
# 1    2015-12-12 19:00:00  Cheikhou Kouyaté          Pass
# 2    2015-12-12 19:00:00   Aaron Cresswell        Aerial
# 3    2015-12-12 19:00:00    Angelo Ogbonna       Chipped
# 4    2015-12-12 19:00:00  Cheikhou Kouyaté  BallRecovery
# ..                   ...               ...           ...
# 374  2021-08-28 14:00:00   Aaron Cresswell          Pass
# 375  2021-08-28 14:00:00       Declan Rice  BallRecovery
# 376  2021-08-28 14:00:00              None          None
# 377  2021-09-11 14:00:00     Said Benrahma          Pass
# 378  2021-09-11 14:00:00     Nikola Vlasic          Pass
#
# [377 rows x 20 columns]
